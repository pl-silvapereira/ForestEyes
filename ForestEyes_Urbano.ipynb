# %% [markdown]
# <a href="https://colab.research.google.com/github/pl-silvapereira/ForestEyes/blob/develop/ForestEyes_Urbano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python '/home/ProjectFiles/scripts/01-Classificacao.py'
# Out:
# 📖 Lendo arquivo: 2023_coverage_coverage_10m_1-95-2928_faf8d377-614d-4e94-a539-5201bc76c6ef.tif
# 📐 Vetorizando apenas as classes de interesse...
# 🧹 Filtrando ruídos pequenos...
# 🎨 Gerando arquivo de estilo: SJC_Classificado.qml
# ✅ Concluído! O arquivo SJC_Classificado.shp agora tem estilo automático.

# %%
# !python '/home/ProjectFiles/scripts/02-Download_INPE.py'
# Out:
# 📄 Lendo links de: inpe_catalog_2026_4_6_19_24_3.txt
# 🚀 Iniciando download de 10 arquivos...
#
# [1/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND0.tif: 100% 2.34G/2.34G [02:17<00:00, 18.2MiB/s]
#
# [2/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND0.xml: 19.4kiB [00:00, 1.14MiB/s]
#
# [3/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND1.tif: 100% 123M/123M [00:08<00:00, 15.8MiB/s]
#
# [4/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND1.xml: 19.4kiB [00:00, 13.1MiB/s]
#
# [5/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND2.tif: 100% 137M/137M [00:10<00:00, 14.3MiB/s]
#
# [6/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND2.xml: 19.4kiB [00:00, 1.45MiB/s]
#
# [7/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND3.tif: 100% 148M/148M [00:09<00:00, 15.7MiB/s]
#
# [8/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND3.xml: 19.4kiB [00:00, 1.50MiB/s]
#
# [9/10]
# CBERS_4A_WPM_20230724_202_142_L4_BAND4.tif: 100% 180M/180M [00:11<00:00, 16.1MiB/s]
#
# [10/10]
# ...

# %%
# !python '/home/ProjectFiles/scripts/03-Pansharpening_SJC.py'
# Out:
# 🚀 Iniciando Fusão (Pan-sharpening)...
#
#
# ✅ Concluído! Imagem de SJC gerada: SJC_CBERS4A_WPM_Final_05m.tif
