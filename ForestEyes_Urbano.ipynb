# %% [markdown]
# <a href="https://colab.research.google.com/github/pl-silvapereira/ForestEyes/blob/develop/ForestEyes_Urbano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

# 1. Conecta o seu Google Drive (vai pedir autorização)
drive.mount('/content/drive')

# 2. Define o caminho exato de destino no seu Drive
caminho_destino = "/content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/scripts"

# Garante que a pasta de destino exista
os.makedirs(caminho_destino, exist_ok=True)

print("Baixando o repositório...")

# 3. Comandos de terminal integrados para baixar e mover os arquivos
# Remove qualquer pasta temporária antiga
# !rm -rf /tmp/ForestEyes_temp

# Clona APENAS a branch 'develop' (usando --single-branch fica muito mais rápido)
# !git clone -b develop --single-branch https://github.com/pl-silvapereira/ForestEyes.git /tmp/ForestEyes_temp

print("Copiando a pasta 'scripts' para o Google Drive...")

# Copia os arquivos da pasta scripts para o seu Drive
# (As aspas em "{caminho_destino}" protegem o espaço no nome da sua pasta)
# !cp -r /tmp/ForestEyes_temp/scripts/* "{caminho_destino}/"

# Limpa a lixeira (apaga o resto do repositório que não precisamos)
# !rm -rf /tmp/ForestEyes_temp

print("✅ Download e cópia concluídos com sucesso!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Baixando o repositório...
# Cloning into '/tmp/ForestEyes_temp'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 118 (delta 14), reused 40 (delta 6), pack-reused 63 (from 1)
# Receiving objects: 100% (118/118), 55.98 MiB | 37.37 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Copiando a pasta 'scripts' para o Google Drive...
# ✅ Download e cópia concluídos com sucesso!

# %%
# !python '/content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/scripts/01_Setup_Environment.py'
# Out:
# ✅ Ambiente ForestEyes pronto.

# %%
# !python '/content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/scripts/02_Check_MapBiomas_Ref.py'
# Out:
# Iniciando verificação espacial e metadados...
#
# === Verificando Referência MapBiomas ===
# 🔍 Referência MapBiomas: 2023_coverage_coverage_10m_1-95-2928_faf8d377-614d-4e94-a539-5201bc76c6ef.tif
#    - Sistema de Coordenadas (CRS) Nativo: EPSG:4326
#    - Dimensões: 4415x5562
#    - Extensão (Bounds Nativos): BoundingBox(left=-46.11294898512216, bottom=-23.311371454429995, right=-45.71634278718339, top=-22.81172849340272)
#
# 📍 Limites extraídos via Raster MapBiomas:
# -----------------------------------
# Norte (Lat): -22.811728
# Sul   (Lat): -23.311371
# Leste (Lon): -45.716343
# Oeste (Lon): -46.112949
# -----------------------------------
# Bounding Box (W, S, E, N): -46.112949, -23.311371, -45.716343, -22.811728
#
# Verificação concluída.

# %%
# !python '/content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/scripts/03-Classificacao.py'
# Out:
# 📖 A processar e enriquecer dados ISO: 2023_coverage_coverage_10m_1-95-2928_faf8d377-614d-4e94-a539-5201bc76c6ef.tif
# ✅ Shapefile enriquecido com normas ISO gerado: SJC_Classificado_ForestEyes.shp
# 🎨 Estilo QML gerado com sucesso: SJC_Classificado_ForestEyes.qml

# %%
# !python '/content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/scripts/04-Download_INPE.py'
# Out:
# 🚀 Baixando 10 arquivos para /content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/data/CBERS4A-WPM/Downloads...
# CBERS_4A_WPM_20230724_202_142_L4_BAND0.tif: 100% 2.52G/2.52G [01:39<00:00, 25.4MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND0.xml: 19.9kiB [00:00, 1.62MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND1.tif: 100% 129M/129M [00:11<00:00, 11.4MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND1.xml: 19.9kiB [00:00, 25.8MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND2.tif: 100% 144M/144M [00:16<00:00, 8.97MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND2.xml: 19.9kiB [00:00, 39.2MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND3.tif: 100% 155M/155M [00:06<00:00, 22.8MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND3.xml: 19.9kiB [00:00, 44.0MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND4.tif: 100% 189M/189M [00:16<00:00, 11.7MiB/s]
# CBERS_4A_WPM_20230724_202_142_L4_BAND4.xml: 19.9kiB [00:00, 44.2MiB/s]

# %%
# !python '/content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes/scripts/05-Pansharpening_SJC.py'
# Out:
# Diretório Raiz: /content/drive/MyDrive/Mestrado/04-Projeto ForestEyes/ForestEyes
# 🚀 Iniciando Pansharpening com Alinhamento Geográfico (VRT)...
#   📊 Progresso da Fusão: 15.4%
